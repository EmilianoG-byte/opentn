  2.2727003028107707e-05,
  2.255143419264146e-05,
  2.2081067627549385e-05,
  2.2081067627549385e-05,
  2.1916868666048118e-05,
  2.1829922448452923e-05,
  2.170379364563597e-05,
  2.170379364563597e-05,
  2.1673280404942515e-05,
  2.16507501096833e-05,
  2.16507501096833e-05,
  2.1644487386100416e-05,
  2.1630776247914598e-05,
  2.1630776247914598e-05,
  2.1627774210470647e-05,
  2.1627774210470647e-05,
  2.162352215444736e-05,
  2.1620502279300183e-05,
  2.1616052589101928e-05],
 [5.686635658263572e-05,
  5.686635658263572e-05,
  5.686635658263572e-05,
  4.8653785234652965e-05,
  4.441391770038193e-05,
  4.2186704077237626e-05,
  3.8095806922925275e-05,
  3.8095806922925275e-05,
  3.61539547126842e-05,
  3.52913895318953e-05,
  3.2561954074803626e-05,
  3.2561954074803626e-05,
  3.1209075435681226e-05,
  3.0379262955424347e-05,
  3.0379262955424347e-05,
  2.9289006593855226e-05,
  2.83518641181683e-05,
  2.83518641181683e-05,
  2.745246401404119e-05,
  2.6826605095488262e-05,
  2.6826605095488262e-05,
  2.5801105284215498e-05,
  2.5354157665134368e-05,
  2.4165196138908446e-05,
  2.3497418707703694e-05,
  2.3497418707703694e-05,
  2.2980781425466462e-05,
  2.2895251681229663e-05,
  2.2306963504339118e-05,
  2.225829581142403e-05,
  2.1967243429569845e-05,
  2.1925720159715916e-05,
  2.184987653496258e-05,
  2.1775321554704027e-05,
  2.1775321554704027e-05,
  2.1721485101772893e-05,
  2.168215402922807e-05,
  2.168215402922807e-05,
  2.1653016568534858e-05,
  2.1653016568534858e-05]]

# %% [markdown]
# ## Plot

# %%
labels = ["rank 2", "rank 4", "rank 8", "rank 16"]
title = r"Kitaev: $\tau = 0.5,  n_\tau = 4$"
fig = plot_pretty(
    f_kitaev_n4_ranks,
    labels=labels,
    ylabel="Cost Function Value",
    xlabel="Iteration",
    integers=True,
    title=title,
    legend_out=True,
    comparison_value=None,
    optimize=True,
    inset=True,
    inset_idx=32,
    inset_label=True,
    marker_step=2
    )

# %%
fig.savefig('../images/paper/cost_ranks_kitaev_n4_paper.pdf', bbox_inches='tight')

# %% [markdown]
# # Convergence comparison

# %% [markdown]
# ## Extra data

# %%
# from https://github.com/EmilianoG-byte/opentn/blob/c4f830653e91a866ae934e613d788996423f0764/experiments/structure_preserving.ipynb
# this is raw data from the graphs-thesis-extra branch

f_timestep_1_tau_1_opt_extra = [
    0.005992052805369189, 0.005179546089612317, 0.00496886996117253,
    0.004967157117125347, 0.0049671571139104885, 0.004967157113910482,
    0.004967157113910482, 0.004967157113910482, 0.004967157113910482,
    0.004967157113910482, 0.004967157113910482, 0.004967157113910482,
    0.004967157113910482, 0.004967157113910482, 0.004967157113910482,
    0.004967157113910482, 0.004967157113910482, 0.004967157113910482,
    0.004967157113910482, 0.004967157113910482
]

f_timestep_2_tau_1_opt_extra = [
    0.0015003228414406608, 0.0015003228414406608, 0.0012901493693791082,
    0.001196972130768543, 0.0011487127266601046, 0.0011487127266601046,
    9.382169141749915e-05, 9.367315002679917e-05, 9.326049152600047e-05,
    9.301878661388253e-05, 9.271659225345586e-05, 9.242204686620634e-05,
    9.231651651770628e-05, 9.228907816119386e-05
]

# %% [markdown]
# ## Postprocess

# %%
f_stiefel_ts = [
    f_timestep_1_tau_1_opt_extra,
    f_timestep_2_tau_1_opt_extra[:25],
    f_timestep_3_tau_1_opt_extra[:25],
    f_timestep_4_tau_1_opt_extra[:25],
    f_timestep_5_tau_1_opt_extra
    ]

ratios_ts = []
for f_ts in f_stiefel_ts:
    ratios_ts.append([f/f_ts[0] for f in f_ts])

# %% [markdown]
# ## Plot

# %%
labels = [rf"$n_\tau = {i}$" for i in range(1,len(ratios_ts)+1)]
title = r"Kitaev: $\tau = 1, \mathrm{R}=2$"
fig = plot_pretty(
    ydatas=ratios_ts,
    labels=labels,
    ylabel="Cost Function Normalized",
    xlabel="Iteration",
    integers=True,
    optimize=False,
    legend_out=False,
    title=title,
)

# %%
fig.savefig('../images/paper/cost_kitaev_timesteps_convergence_scaled_paper.pdf', bbox_inches='tight')

# %% [markdown]
# # Metric comparison

# %% [markdown]
# ## Load data

# %%
f_canonical_elementary_loaded = np.load(file="f_pauli_n4_tau05_rank2.npy")

# %% [markdown]
# ## Extra data

# %%
f_euclidean_loaded = [
    5.686635658284696e-05, 5.686635658284696e-05, 5.686635658284696e-05,
    5.686635658284696e-05, 5.686635658284696e-05, 5.686635658284696e-05,
    5.2036373684395244e-05, 4.8376958733568486e-05, 4.8033905431655804e-05,
    4.762307091604486e-05, 4.758863687136877e-05, 4.755315272993174e-05,
    4.755315272993174e-05, 4.75492634048074e-05, 4.75492634048074e-05,
    4.75492634048074e-05, 4.754871326311625e-05, 4.754797829668925e-05,
    4.754797829668925e-05, 4.754766136965826e-05
]

f_euclidean_elementary_loaded = [
    5.686635658284696e-05, 5.686635658284696e-05, 5.686635658284696e-05,
    4.8509921486314255e-05, 4.439438954482699e-05, 4.280850524708458e-05,
    4.233136275764096e-05, 4.200786177185326e-05, 4.1340389145019885e-05,
    4.056956447972166e-05, 4.0300227755542985e-05, 3.983607518336135e-05,
    3.943434983011074e-05, 3.907720374236262e-05, 3.8476875056437035e-05,
    3.741864295612718e-05, 3.703842598921613e-05, 3.662344760188464e-05,
    3.662344760188464e-05, 3.622980141910336e-05
]

# %% [markdown]
# ## Plot

# %%
f_kitaev_n4 = [f_euclidean_loaded, f_euclidean_elementary_loaded, f_canonical_elementary_loaded[:20]]
labels = [r'$G^{[1,1]}$ + $\pi_T(E_{ij})$', r'$G^{[1,1]}$ + $(E^A_{ij}, E^B_{ij})$', r'$G^{[1,1/2]}$ + $(E^A_{ij}, E^B_{ij})$']
title = r"Kitaev: $\tau = 0.5,  n_\tau = 4$"
fig = plot_pretty(
    f_kitaev_n4,
    labels=labels,
    ylabel="Cost Function Value",
    xlabel="Iteration",
    integers=True,
    title=title,
    legend_out=False
    )

# %%
fig.savefig('../images/paper/cost_param_kitaev_n4_paper.pdf', bbox_inches='tight')
